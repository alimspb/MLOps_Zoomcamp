# %%
# You can also check the version programmatically in Python
import mlflow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # You can also check the version programmatically in Python
# ----> 2 import mlflow
#
# File ~/PycharmProjects/ml_ops_practice/.venv/lib/python3.12/site-packages/mlflow/__init__.py:44
#      41     mlflow.mismatch._check_version_mismatch()
#      43 if not IS_TRACING_SDK_ONLY:
# ---> 44     from mlflow import (
#      45         artifacts,  # noqa: F401
#      46         client,  # noqa: F401
#      47         config,  # noqa: F401
#      48         data,  # noqa: F401
#      49         exceptions,  # noqa: F401
#      50         genai,  # noqa: F401
#      51         models,  # noqa: F401
#      52         projects,  # noqa: F401
#      53         tracking,  # noqa: F401
#      54     )
#      56 from mlflow import tracing  # noqa: F401
# ...
